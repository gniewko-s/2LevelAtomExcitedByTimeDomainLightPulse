# %%
from TwoLevelAtom.inputpulse import *
from TwoLevelAtom.singlephoton import *
from TwoLevelAtom.twophoton import *
import matplotlib.pylab as plt
import numpy as np
from multiprocessing import Pool
import numpy as np
from time import time
import random
import sys
from scipy.integrate import odeint, solve_ivp, quad
from scipy.optimize import minimize, minimize_scalar

# %%
Experiment = SinglePhoton(Rectangular,Gamma = 1.7507513489520856, Omega = 1.3793727551655788,nBins = 10000)
t, p = Experiment.P()
plt.plot(t,p)

# %%
Experiment = TwoPhoton(Rectangular,Gamma = 1.7507513489520856, Omega = 1.3793727551655788,Omega_2 = 2 , Mu = 3,nBins = 1000)
t, p = Experiment.P()
plt.plot(t,p)
