# %%
import TwoLevelSystem as L2 
from inputpulse import *
import ThreeLevelSystem as L3 
import matplotlib.pylab as plt
import numpy as np
from multiprocessing import Pool
import numpy as np
from time import time
import random
import sys
from scipy.integrate import odeint, solve_ivp, quad
from scipy.optimize import minimize, minimize_scalar

# %%
Experiment = L2.SinglePhoton(Rectangular,Gamma = 1.7507513489520856, Omega = 1.3793727551655788,nBins = 10000)
t, p = Experiment.P()
plt.plot(t,p)

# %%
Experiment = L2.TwoPhoton(Rectangular,Gamma = 1.7507513489520856, Omega = 1.3793727551655788,Omega_2 = 2 , Mu = 3,nBins = 1000)
t, p = Experiment.P()
plt.plot(t,p)

# %%
Experiment = L3.TwoPhoton(ExpoRaising, Omega_1= 0.8188612199044147, Gamma_1= 1, Omega_2= 1.7505153724152838,
                Gamma_2= 1,Mu = 0, nBins = 1000)
t, p = Experiment.P()
plt.plot(t,p)
# Out:
# /home/masood/Projects/TwoPhotonAbsorption/2LevelAtomExcitedByTimeDomainLightPulse/LightMatterInteraction/inputpulse.py:17: RuntimeWarning: overflow encountered in exp
#   return np.where( t < Mu ,np.sqrt(Omega)*np.exp(Omega*(t-Mu)/2) , 0)

# %%
Experiment = L2.TwoPhoton(Rectangular,Gamma = 1.7507513489520856, Omega = 1.3793727551655788,Omega_2 = 2 , Mu = 3,nBins = 1000)
t, p = Experiment.P()
plt.plot(t,p)
